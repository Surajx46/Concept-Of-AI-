# %% [markdown]
# 3 Tasks- To- Do:
#
#  Please Solve all the Problems as instructed:
#  3.1 Problem- 1: Getting Started with Data Exploration- Some Warm up
#  Exercises:
#  1. Data Exploration and Understanding

# %%
#Load the Dataset and Display the First 10 Rows
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns


# Load the dataset
df = pd.read_csv("/content/drive/MyDrive/AI dataset/Datasets-20241202T063912Z-001/Datasets/WHR-2024-5CS037.csv")

# Display the first 10 rows
df.head(10)
# Out:
#   Country name  score  Log GDP per capita  Social support  \
# 0      Finland  7.741               1.844           1.572
# 1      Denmark  7.583               1.908           1.520
# 2      Iceland  7.525               1.881           1.617
# 3       Sweden  7.344               1.878           1.501
# 4       Israel  7.341               1.803           1.513
# 5  Netherlands  7.319               1.901           1.462
# 6       Norway  7.302               1.952           1.517
# 7   Luxembourg  7.122               2.141           1.355
# 8  Switzerland  7.060               1.970           1.425
# 9    Australia  7.057               1.854           1.461
#
#    Healthy life expectancy  Freedom to make life choices  Generosity  \
# 0                    0.695                         0.859       0.142
# 1                    0.699                         0.823       0.204
# 2                    0.718                         0.819       0.258
# ...

# %% [markdown]
# 2.Identiy the number of rows and columns in the dataset

# %%
#2. Identify the number of rows and columns in the dataset.
# Get the shape of the dataset
rows, columns = df.shape
(rows, columns)
# Out:
# (143, 9)

# %% [markdown]
#  3. List all the columns and their data types.

# %%
#3. List columns and their data types
df.dtypes
# Out:
# Country name                     object
# score                           float64
# Log GDP per capita              float64
# Social support                  float64
# Healthy life expectancy         float64
# Freedom to make life choices    float64
# Generosity                      float64
# Perceptions of corruption       float64
# Dystopia + residual             float64
# dtype: object

# %% [markdown]
# Basic Statistics:
#  1. Calculate the mean, median, and standard deviation for the Score column.

# %%
# Get summary statistics
df.describe()
# Out:
#             score  Log GDP per capita  Social support  \
# count  143.000000          140.000000      140.000000
# mean     5.527580            1.378807        1.134329
# std      1.170717            0.425098        0.333317
# min      1.721000            0.000000        0.000000
# 25%      4.726000            1.077750        0.921750
# 50%      5.785000            1.431500        1.237500
# 75%      6.416000            1.741500        1.383250
# max      7.741000            2.141000        1.617000
#
#        Healthy life expectancy  Freedom to make life choices  Generosity  \
# count               140.000000                    140.000000  140.000000
# mean                  0.520886                      0.620621    0.146271
# std                   0.164923                      0.162492    0.073441
# min                   0.000000                      0.000000    0.000000
# 25%                   0.398000                      0.527500    0.091000
# ...

# %%
# 1. Calculate the mean, median, and standard deviation for the Score column.
mean_score = df['score'].mean()
median_score = df['score'].median()
std_score = df['score'].std()

(mean_score, median_score, std_score)
# Out:
# (5.52758041958042, 5.785, 1.1707165099442995)

# %% [markdown]
#  2. Identify the country with the highest and lowest happiness scores

# %%
# Identify countries with the highest and lowest happiness scores.
highest_score = df.loc[df['score'].idxmax()]
lowest_score = df.loc[df['score'].idxmin()]

(highest_score['Country name'], highest_score['score'], lowest_score['Country name'], lowest_score['score'])
# Out:
# ('Finland', 7.741, 'Afghanistan', 1.721)

# %% [markdown]
#  Missing Values:
#  1. Check if there are any missing values in the dataset. If so, display the total count for each column

# %%
# missing_values
missing_values = df.isnull().sum()
missing_values[missing_values >0]
# Out:
# Log GDP per capita              3
# Social support                  3
# Healthy life expectancy         3
# Freedom to make life choices    3
# Generosity                      3
# Perceptions of corruption       3
# Dystopia + residual             3
# dtype: int64

# %% [markdown]
# • Filtering and Sorting:
#  1. Filter the dataset to show only the countries with a Score greater than 7.5."

# %%
# Filter dataset
high_score_countries = df[df['score'] > 7.5]
high_score_countries
# Out:
#   Country name  score  Log GDP per capita  Social support  \
# 0      Finland  7.741               1.844           1.572
# 1      Denmark  7.583               1.908           1.520
# 2      Iceland  7.525               1.881           1.617
#
#    Healthy life expectancy  Freedom to make life choices  Generosity  \
# 0                    0.695                         0.859       0.142
# 1                    0.699                         0.823       0.204
# 2                    0.718                         0.819       0.258
#
#    Perceptions of corruption  Dystopia + residual
# 0                      0.546                2.082
# 1                      0.548                1.881
# 2                      0.182                2.050

# %% [markdown]
#  2. For the filtered dataset- Sort the dataset by GDP per Capita in descending order and display the
#  top 10 rows

# %%
#  display the top 10 rows.
# Sort by GDP per Capita and display top 10
top_gdp_countries = df.sort_values(by='Log GDP per capita', ascending=False).head(10)
top_gdp_countries
# Out:
#                  Country name  score  Log GDP per capita  Social support  \
# 7                  Luxembourg  7.122               2.141           1.355
# 16                    Ireland  6.838               2.129           1.390
# 29                  Singapore  6.523               2.118           1.361
# 21       United Arab Emirates  6.733               1.983           1.164
# 8                 Switzerland  7.060               1.970           1.425
# 6                      Norway  7.302               1.952           1.517
# 22              United States  6.725               1.939           1.392
# 85  Hong Kong S.A.R. of China  5.316               1.909           1.184
# 1                     Denmark  7.583               1.908           1.520
# 5                 Netherlands  7.319               1.901           1.462
#
#     Healthy life expectancy  Freedom to make life choices  Generosity  \
# 7                     0.708                         0.801       0.146
# ...

# %% [markdown]
#  • Adding New Columns:
#  1. Create a new column called Happiness Category that categorizes countries into three categories
#  based on their Score:

# %%
# Create a new column for Happiness Category
def  happiness_category(score):
    if score >= 6:
        return 'High'
    elif score >= 5:
        return 'Medium'
    else:
        return 'Low'

df['Happiness Category'] = df['score'].apply(happiness_category)
df.head()
# Low − (Score < 4)
# Medium − (4 ≤ Score ≤ 6)
# High − (Score > 6)
# Out:
#   Country name  score  Log GDP per capita  Social support  \
# 0      Finland  7.741               1.844           1.572
# 1      Denmark  7.583               1.908           1.520
# 2      Iceland  7.525               1.881           1.617
# 3       Sweden  7.344               1.878           1.501
# 4       Israel  7.341               1.803           1.513
#
#    Healthy life expectancy  Freedom to make life choices  Generosity  \
# 0                    0.695                         0.859       0.142
# 1                    0.699                         0.823       0.204
# 2                    0.718                         0.819       0.258
# 3                    0.724                         0.838       0.221
# 4                    0.740                         0.641       0.153
#
#    Perceptions of corruption  Dystopia + residual Happiness Category
# 0                      0.546                2.082               High
# ...

# %% [markdown]
#  2. Data Visualizations:
#
#  • Bar Plot: Plot the top 10 happiest countries by Score using a bar chart.

# %%
top_happy = df.nlargest(10, 'score')
bars = plt.barh(top_happy['Country name'], top_happy['score'], color='skyblue', edgecolor='black')
plt.xlabel('Happiness Score')
plt.ylabel('Country')
plt.title('Top 10 Happiest Countries')
plt.show()

# %% [markdown]
#  • Line Plot: Plot the top 10 unhappiest countries by Score using a Line chart.

# %%
top_unhappy = df.nsmallest(10, 'score')
plt.plot(top_unhappy['Country name'], top_unhappy['score'], marker='o', linestyle='-', color='coral')

plt.ylabel('Happiness Score')
plt.xlabel('Country')
plt.title('Top 10 Unhappiest Countries')
plt.xticks(rotation= 90)
plt.show()

# %% [markdown]
# • Plot a histogram for the Score column to show its distribution and also interpret.

# %%
plt.hist(df['score'], bins=20, color='brown', edgecolor='black')
plt.xlabel('Happiness Score')
plt.ylabel('Frequency')
plt.title('Distribution of Happiness Scores')
plt.show()

# %% [markdown]
#  • Scatter Plot:
#
#  Plot a scatter plot between GDP per Capita and Score to visualize their relationship.

# %%
plt.scatter(df['Log GDP per capita'], df['score'], alpha=0.5, color='blue')
plt.title('Scatter plot of Log GDP per capita vs Happiness Score')
plt.xlabel('Log GDP per Capita')
plt.ylabel('Happiness Score')
plt.show()

# %% [markdown]
#  3.2 Problem- 2- Some Advance Data Exploration Task:
#
#  Task- 1- Setup Task- Preparing the South-Asia Dataset

# %%
# 1. Define the countries in South Asia with a list for example:
# south asian countries = ["Afghanistan", "Bangladesh", "Bhutan", "India", "Maldives", "Nepal", "Pakistan", "Srilanka"]

# Define South Asian countries
south_asian_countries = ['Bangladesh', 'Bhutan', 'India', 'Maldives', 'Nepal', 'Pakistan', 'Sri Lanka', 'Afghanistan']

# Save the filtered data to a file
south_asia_df.to_csv('south_asia_df.csv', index=False)

# %%
# 2. Use the list from step - 1 to filtered the dataset {i.e. filtered out matching dataset from list.}
# Filter the dataset
south_asia_df = df[df['Country name'].isin(south_asian_countries)]
south_asia_df.head()
# south_asia_data.tail()
# Out:
#     Country name  score  Log GDP per capita  Social support  \
# 92         Nepal  5.158               0.965           0.990
# 107     Pakistan  4.657               1.069           0.600
# 125        India  4.054               1.166           0.653
# 127    Sri Lanka  3.898               1.361           1.179
# 128   Bangladesh  3.886               1.122           0.249
#
#      Healthy life expectancy  Freedom to make life choices  Generosity  \
# 92                     0.443                         0.653       0.209
# 107                    0.321                         0.542       0.144
# 125                    0.417                         0.767       0.174
# 127                    0.586                         0.583       0.144
# 128                    0.513                         0.775       0.140
#
#      Perceptions of corruption  Dystopia + residual Happiness Category
# 92                       0.115                1.783             Medium
# ...

# %% [markdown]
# 3. Save the filtered dataframe as separate CSV files for future use

# %%
# Save the filtered data to a file
south_asia_df.to_csv('south_asia_df.csv', index=False)

# %% [markdown]
#  Task- 2- Composite Score Ranking:
#  Tasks:
#  1. Using the SouthAsia DataFrame, create a new column called Composite Score that combines the
#  following metrics:
#
#  Composite Score = 0.40×GDP per Capita+0.30×Social Support + 0.30 × Healthy Life Expectancy

# %%
# Create Composite Score
south_asia_df['Composite Score'] = (0.40 * south_asia_df['Log GDP per capita'] +
                                       0.30 * south_asia_df['Social support'] +
                                       0.30 * south_asia_df['Healthy life expectancy'])
south_asia_df.head()
# Out:
# <ipython-input-20-5e9600a898dd>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   south_asia_df['Composite Score'] = (0.40 * south_asia_df['Log GDP per capita'] +
#     Country name  score  Log GDP per capita  Social support  \
# 92         Nepal  5.158               0.965           0.990
# 107     Pakistan  4.657               1.069           0.600
# 125        India  4.054               1.166           0.653
# 127    Sri Lanka  3.898               1.361           1.179
# 128   Bangladesh  3.886               1.122           0.249
#
#      Healthy life expectancy  Freedom to make life choices  Generosity  \
# 92                     0.443                         0.653       0.209
# ...

# %% [markdown]
#  2. Rank the South Asian countries based on the Composite Score in descending order.

# %%
# Rank countries based on Composite Score
south_asia_ranked = south_asia_df.sort_values(by='Composite Score', ascending=False)
top_5_south_asia = south_asia_ranked.head(5)
top_5_south_asia
# Out:
#     Country name  score  Log GDP per capita  Social support  \
# 127    Sri Lanka  3.898               1.361           1.179
# 92         Nepal  5.158               0.965           0.990
# 125        India  4.054               1.166           0.653
# 107     Pakistan  4.657               1.069           0.600
# 128   Bangladesh  3.886               1.122           0.249
#
#      Healthy life expectancy  Freedom to make life choices  Generosity  \
# 127                    0.586                         0.583       0.144
# 92                     0.443                         0.653       0.209
# 125                    0.417                         0.767       0.174
# 107                    0.321                         0.542       0.144
# 128                    0.513                         0.775       0.140
#
#      Perceptions of corruption  Dystopia + residual Happiness Category  \
# 127                      0.031                0.014                Low
# ...

# %% [markdown]
# 3. Visualize the top 5 countries using a horizontal bar chart showing the Composite Score.

# %%
plt.barh(top_5_south_asia['Country name'], top_5_south_asia['Composite Score'], color='purple')
plt.xlabel('Composite Score')
plt.ylabel('Country')
plt.title('Top 5 South Asian Countries by Composite Score')
# Out:
# Text(0.5, 1.0, 'Top 5 South Asian Countries by Composite Score')

# %% [markdown]
#  4. Discuss whether the rankings based on the Composite Score align with the original Score- support your
#  discussion with some visualization plot

# %% [markdown]
# Summary Analysis
# The scatter plot compares the original rankings with composite score rankings. Ideally, the points should form a straight diagonal line, but any deviations from the line indicate changes in the rankings.
#
# Key Observations
# Maldives improved in ranking after the calculation of the composite score.
# Sri Lanka, India, and Bangladesh dropped in rank.
# Nepal, Bhutan, and Pakistan retained their positions.
# Overall, there are some misalignments between the original and composite score rankings

# %% [markdown]
# Task- 3- Outlier Detection:
#
#  Tasks
#
#   1. Identify outlier countries in South Asia based on their Score and GDP per Capita

# %%
score_outliers = south_asia_df[south_asia_df['score'] > 7.5]
gdp_outliers = south_asia_df[south_asia_df['Log GDP per capita'] > 5]
(score_outliers, gdp_outliers)
# Out:
# (Empty DataFrame
#  Columns: [Country name, score, Log GDP per capita, Social support, Healthy life expectancy, Freedom to make life choices, Generosity, Perceptions of corruption, Dystopia + residual, Happiness Category, Composite Score]
#  Index: [],
#  Empty DataFrame
#  Columns: [Country name, score, Log GDP per capita, Social support, Healthy life expectancy, Freedom to make life choices, Generosity, Perceptions of corruption, Dystopia + residual, Happiness Category, Composite Score]
#  Index: [])

# %% [markdown]
# 2. Define outliers using the 1.5 × IQR rule

# %%
#  Define outliers using 1.5 × IQR rule
Q1 = south_asia_df['score'].quantile(0.25)
Q3 = south_asia_df['score'].quantile(0.75)
IQR = Q3 - Q1
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

outliers = south_asia_df[(south_asia_df['score'] < lower_bound) | (south_asia_df['score'] > upper_bound)]

# %% [markdown]
#  3. Create a scatter plot with GDP per Capita on the x-axis and Score on the y-axis, highlighting outliers
#  in a different color

# %%
# Scatter plot highlighting outliers
plt.scatter(south_asia_df['Log GDP per capita'], south_asia_df['score'], color='teal', label='Data Points')
plt.scatter(outliers['Log GDP per capita'], outliers['score'], color='yellow', label='Outliers')
plt.xlabel('Log GDP per Capita')
plt.ylabel('Happiness Score')
plt.title('Scatter Plot with Outliers')
plt.legend()
plt.show()

# %% [markdown]
#  4. Discuss the characteristics of these outliers and their potential impact on regional averages.

# %% [markdown]
# Outliers are those points that are located farthest from others such as countries with very high or low ‘scores’or ‘Log GDP per capita’; as compared to the countries in South Asia. Such outliers can grossly affect regional averages: the means and medians in particular. This is because a high ‘score’ will increase the averaged ‘score’, as will a low score decrease the averaged ‘score’. However, if the data contain outliers, the mean is more likely to be affected so both should be checked. Sometimes exclusion of such outliers can make the data more realistic for typical scenarios; this is achievable only if one is well anchored in the context of an application

# %% [markdown]
#  Task- 4- Exploring Trends Across Metrics:
#  Tasks:
#  1. Choose two metrics (e.g., Freedom to Make Life Choices and Generosity) and calculate their correlation
#  {pearson correlation} with the Score for South Asian countries.

# %%
correlation = south_asia_df[['Freedom to make life choices', 'Generosity', 'score']].corr()
correlation
# Out:
#                               Freedom to make life choices  Generosity  \
# Freedom to make life choices                      1.000000    0.733396
# Generosity                                        0.733396    1.000000
# score                                             0.800519    0.874512
#
#                                  score
# Freedom to make life choices  0.800519
# Generosity                    0.874512
# score                         1.000000

# %% [markdown]
# 2. Create scatter plots with trendlines for these metrics against the Score

# %%
# Scatter plots with trendlines
plt.scatter(south_asia_df['Freedom to make life choices'], south_asia_df['score'], color='teal', label='Data Points')
plt.title('Scatter Plot of Freedom to Make Life Choices vs Happiness Score')
plt.xlabel('Freedom to Make Life Choices')
plt.ylabel('Happiness Score')
plt.grid(True)
plt.show()

# %% [markdown]
#  3. Identify and discuss the strongest and weakest relationships between these metrics and the Score for
#  South Asian countries

# %% [markdown]
# correlation between GDP per Capita and Score: -0.8032119615639224
#
# Correlation between Social Support and Score: 0.2638493236460215
#
# Correlation between Healthy Life Expectancy and Score: -0.5607608963278004
#
# Correlation between Freedom to Make Life Choices and Score: -0.38853783610310855
#
# Correlation between Generosity and Score: 0.7153818875662525
#
# Strongest and Weakest Relationships
# The strongest relationship with Score is Generosity (Correlation: 0.72)
#
# The weakest relationship with Score is GDP per Capita (Correlation: -0.80)

# %% [markdown]
#  Task- 5- Gap Analysis:
#  Tasks:
#  1. Add a new column, GDP-Score Gap, which is the difference between GDP per Capita and the Score
#  for each South Asian country

# %%
# Add a new column, GDP-Score Gap
south_asia_df['GDP-Score Gap'] = south_asia_df['Log GDP per capita'] - south_asia_df['score']

# Display the updated DataFrame
south_asia_df.head()
# Out:
# <ipython-input-28-1f8e07d8a1c0>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   south_asia_df['GDP-Score Gap'] = south_asia_df['Log GDP per capita'] - south_asia_df['score']
#     Country name  score  Log GDP per capita  Social support  \
# 92         Nepal  5.158               0.965           0.990
# 107     Pakistan  4.657               1.069           0.600
# 125        India  4.054               1.166           0.653
# 127    Sri Lanka  3.898               1.361           1.179
# 128   Bangladesh  3.886               1.122           0.249
#
#      Healthy life expectancy  Freedom to make life choices  Generosity  \
# 92                     0.443                         0.653       0.209
# ...

# %% [markdown]
#  2. Rank the South Asian countries by this gap in both ascending and descending order.

# %%
# Rank by gap
gap_ranked = south_asia_df.sort_values(by='GDP-Score Gap')
top_positive_gap = gap_ranked.head(3)
top_negative_gap = gap_ranked.tail(3)

(top_positive_gap, top_negative_gap)
# Out:
# (    Country name  score  Log GDP per capita  Social support  \
#  92         Nepal  5.158               0.965           0.990
#  107     Pakistan  4.657               1.069           0.600
#  125        India  4.054               1.166           0.653
#
#       Healthy life expectancy  Freedom to make life choices  Generosity  \
#  92                     0.443                         0.653       0.209
#  107                    0.321                         0.542       0.144
#  125                    0.417                         0.767       0.174
#
#       Perceptions of corruption  Dystopia + residual Happiness Category  \
#  92                       0.115                1.783             Medium
#  107                      0.074                1.907                Low
#  125                      0.122                0.756                Low
#
#       Composite Score  GDP-Score Gap
#  92            0.8159         -4.193
#  107           0.7039         -3.588
# ...

# %% [markdown]
# 3. Highlight the top 3 countries with the largest positive and negative gaps using a bar chart

# %%
# Visualize gaps.
plt.barh(top_positive_gap['Country name'], top_positive_gap['GDP-Score Gap'], color='black', label='Positive Gap')
plt.barh(top_negative_gap['Country name'], top_negative_gap['GDP-Score Gap'], color='pink', label='Negative Gap')
plt.title('Top 3 Countries with the Highest GDP-Score Gap')
plt.xlabel('GDP-Score Gap')
plt.ylabel('Country')
plt.show()

# %% [markdown]
# 4. Analyze the reasons behind these gaps and their implications for South Asian countries

# %% [markdown]
# On examining the differential of GDP and scores in SA nations
# The Various Factors that Make or Mar Economic Diversities
#
# Positive Gaps:Economic wellbeing can also be measured in terms of the happiness scores that lower and higher GDP per capita countries have; the latter may experience income inequality whereby only the economic wealth grows.
#
# Negative Gaps:The countries with the lower GDP/ capita and greater happiness indicate that the arm can provide improved social support and social cohesiveness which increases the well-being of a community.
#
# Social and Cultural Factors:This paper suggests that powerful social relations such as family and community enhance happiness irrespective of poor economic status.
# Socio cultural satisfaction and contentment are other factors in the same category.
#
# Governance and Freedom:
# Somewhat relatedly, larger personal freedoms, lesser corruption, and better quality of governance all results in higher happiness.
# On the other hand negative gaps include restricted freedoms or corruption.
#
# Health and Life Expectancy:
# Life expectancy saves life and increases happiness. The funding in healthcare sector could reveal more positive gaps than the countries with poor healthcare facilities result in big negative gaps.
#
# Generosity and Social Cohesion:
# Generosity from individuals and governments influences well-being. Countries with strong social safety nets or community support may have more favorable gaps.
#
# Measurement Limitations:
# Happiness scores are subjective and may not capture all well-being aspects, while GDP per capita does not reflect income distribution or quality of life.
#
# Implications for South Asian Countries
#
# Policy and Development:
# Policymakers can tailor efforts to improve well-being based on gap analysis, focusing on income distribution, job creation, and social welfare for high positive gaps, and on basic needs and healthcare for negative gaps.
#
# Sustainable Development:
# Emphasizing holistic well-being alongside economic growth can lead to sustainable development outcomes.
#
# Social Cohesion:
# Promoting community bonds and generosity can enhance happiness, even in economically challenging times.
#
# Prioritizing Well-being:
# Governments should consider well-being indicators alongside economic success, implementing policies to reduce inequality and improve social support.
#
# Resource Allocation:
# Understanding these gaps can guide resource allocation, prioritizing healthcare and social support over mere economic growth.
#
# Regional Collaboration:
# South Asian countries could benefit from sharing best practices and collaborating on regional development goals to enhance overall well-being.

# %% [markdown]
# Problem3

# %% [markdown]
#  Task- 1- Setup Task- Preparing the Middle Eastern Dataset:
#  Tasks:
#  1. Similar in Task- 1 of Problem 2 create a dataframe from middle eastern countries. For hint use the
#  following list:
#  middle east countries = [ "Bahrain", "Iran", "Iraq", "Israel", "Jordan",
#  "Kuwait", "Lebanon", "Oman", "Palestine", "Qatar", "Saudi Arabia", "Syria",
#  "United Arab Emirates", "Yemen"]

# %%
# Define Middle Eastern countries
middle_eastern_countries = ['Bahrain', 'Cyprus', 'Egypt', 'Israel', 'Jordan', 'Kuwait', 'Lebanon', 'Oman', 'Qatar',
                            'Saudi Arabia', 'Syria', 'Tunisia', 'United Arab Emirates']
middle_eastern_countries
# Out:
# ['Bahrain',
#  'Cyprus',
#  'Egypt',
#  'Israel',
#  'Jordan',
#  'Kuwait',
#  'Lebanon',
#  'Oman',
#  'Qatar',
#  'Saudi Arabia',
#  'Syria',
#  'Tunisia',
#  'United Arab Emirates']

# %%
# Filter the dataset
middle_east_df = df[df['Country name'].isin(middle_eastern_countries)]
middle_east_df.head()
# Out:
#             Country name  score  Log GDP per capita  Social support  \
# 4                 Israel  7.341               1.803           1.513
# 12                Kuwait  6.951               1.845           1.364
# 21  United Arab Emirates  6.733               1.983           1.164
# 27          Saudi Arabia  6.594               1.842           1.361
# 49                Cyprus  6.068               1.794           1.217
#
#     Healthy life expectancy  Freedom to make life choices  Generosity  \
# 4                     0.740                         0.641       0.153
# 12                    0.661                         0.827       0.200
# 21                    0.563                         0.815       0.209
# 27                    0.511                         0.787       0.114
# 49                    0.744                         0.529       0.124
#
#     Perceptions of corruption  Dystopia + residual Happiness Category
# ...

# %%
#Save the filtered dataframe as separate CSV files for future use.
middle_east_df.to_csv('middle_east_df.csv', index=False)

# %% [markdown]
# 3.2(1.Descriptive Statistics:)
#
#  • Calculate the mean, Standard deviation of the score for both South Asia and Middle East

# %%
south_asia_mean = south_asia_df['score'].mean()
middle_east_mean = middle_east_df['score'].mean()
south_asia_std = south_asia_df['score'].std()
middle_east_std = middle_east_df['score'].std()

(south_asia_mean, middle_east_mean, south_asia_std, middle_east_std)
# Out:
# (3.895666666666667, 5.493799999999999, 1.1770690152521504, 1.5546984559357127)

# %% [markdown]
# • Which region has higher happiness Scores on average?

# %% [markdown]
# - the region with the higher average happines score is : Middle East with score of 5.4937999999999

# %% [markdown]
# 2.Top and Bottom Performers:
#
#  • Identify the top 3 and bottom 3 countries in each region based on the score

# %%
# Identify top and bottom performers
south_asia_top = south_asia_df.nlargest(3, 'score')
south_asia_bottom = south_asia_df.nsmallest(3, 'score')
middle_east_top = middle_east_df.nlargest(3, 'score')
middle_east_bottom = middle_east_df.nsmallest(3, 'score')

(south_asia_top, south_asia_bottom, middle_east_top, middle_east_bottom)
# Out:
# (    Country name  score  Log GDP per capita  Social support  \
#  92         Nepal  5.158               0.965           0.990
#  107     Pakistan  4.657               1.069           0.600
#  125        India  4.054               1.166           0.653
#
#       Healthy life expectancy  Freedom to make life choices  Generosity  \
#  92                     0.443                         0.653       0.209
#  107                    0.321                         0.542       0.144
#  125                    0.417                         0.767       0.174
#
#       Perceptions of corruption  Dystopia + residual Happiness Category  \
#  92                       0.115                1.783             Medium
#  107                      0.074                1.907                Low
#  125                      0.122                0.756                Low
#
#       Composite Score  GDP-Score Gap
#  92            0.8159         -4.193
#  107           0.7039         -3.588
# ...

# %% [markdown]
# • Plot bar charts comparing these charts

# %%
# Visualize
plt.barh(south_asia_top['Country name'], south_asia_top['score'], color='pink', label='South Asia Top')
plt.barh(south_asia_bottom['Country name'], south_asia_bottom['score'], color='yellow', label='South Asia Bottom')
plt.barh(middle_east_top['Country name'], middle_east_top['score'], color='pink', label='Middle East Top')
plt.barh(middle_east_bottom['Country name'], middle_east_bottom['score'], color='yellow', label='Middle East Bottom')
plt.title('Top and Bottom Performers in South Asia ')
plt.legend()
plt.show()

# %% [markdown]
# 3. Metric Comparisons:
#
#  • Compare key metrics like GDP per Capita, Social Support, and Healthy Life Expectancy
#  between the regions using grouped bar charts.

# %%
# Compare key metrics
matrics = ['Log GDP per capita','Social support', 'Healthy life expectancy']
south_asia_mean = south_asia_df[matrics].mean()
middle_east_mean = middle_east_df[matrics].mean()

(south_asia_mean, middle_east_mean)
# Out:
# (Log GDP per capita         1.051833
#  Social support             0.611833
#  Healthy life expectancy    0.420333
#  dtype: float64,
#  Log GDP per capita         1.620222
#  Social support             1.125556
#  Healthy life expectancy    0.604000
#  dtype: float64)

# %% [markdown]
# • Which metrics show the largest disparity between the two regions?

# %%
# Create grouped bar charts
import numpy as np
bar_width = 0.35
index = np.arange(len(matrics))

plt.bar(index, south_asia_mean, bar_width, label='South Asia', color='black')
plt.bar(index + bar_width, middle_east_mean, bar_width, label='Middle East', color='red')

plt.xlabel('Metrics')
plt.ylabel('Mean Value')
plt.title('Comparison of Key Metrics')
plt.xticks(index + bar_width / 2, matrics)
plt.legend()
plt.show()

# %% [markdown]
# 4. Happiness Disparity:
#
#  • Compute the range (max- min) and coefficient of variation (CV) for Score in both regions

# %% [markdown]
# • Which region has greater variability in happiness?

# %%
#Compute range (max - min) for each region
range_south_asia = south_asia_df['score'].max() - south_asia_df['score'].min()
range_middle_east = middle_east_df['score'].max() - middle_east_df['score'].min()

#Compute Standard Deviation and Mean for each region
mean_south_asia = south_asia_df['score'].mean()
std_south_asia = south_asia_df['score'].std()

mean_middle_east = middle_east_df['score'].mean()
std_middle_east = middle_east_df['score'].std()

#Compute Coefficient of Variation (CV) for each region
cv_south_asia = (std_south_asia/mean_south_asia) * 100
cv_middle_east = (std_middle_east/mean_middle_east) * 100

#Display result
print("South Asia Happiness Disparity:")
print(f"Range: {range_south_asia}")
print(f"Coefficient of Variation (CV): {cv_south_asia:.2f}%")

print("\nMiddle East Happiness Disparity:")
print(f"Range: {range_middle_east}")
print(f"Coefficient of Variation (CV): {cv_middle_east:.2f}%")

# Determine which region has greater variability

if cv_south_asia > cv_middle_east:
    print("\nSouth Asia has greater variability in happiness.")
elif cv_south_asia < cv_middle_east:
    print("\nMiddle East has greater variability in happiness.")
# Out:
# South Asia Happiness Disparity:
# Range: 3.4370000000000003
# Coefficient of Variation (CV): 30.21%
#
# Middle East Happiness Disparity:
# Range: 4.634
# Coefficient of Variation (CV): 28.30%
#
# South Asia has greater variability in happiness.

# %% [markdown]
# • Which region has greater variability in happiness?
#
# -Middle East has greater variability in happiness.
#
# South Asia Coefficient of Variation: 0.12921921164212014888
#
# Middle East Coefficient of Variation : 0.2829914550831324

# %% [markdown]
#  5. Correlation Analysis:

# %%
# Analyze the correlation of Score with other metrics Freedom to Make Life Choices, and
# Generosity within each region.

# Analyze correlation for South Asia
south_asia_corr = south_asia_df[['score', 'Freedom to make life choices', 'Generosity']].corr()
print("South Asia Correlation:")
print(south_asia_corr)

# Analyze correlation for Middle East
middle_east_corr = middle_east_df[['score', 'Freedom to make life choices', 'Generosity']].corr()
print("\nMiddle East Correlation:")
middle_east_corr

# Create scatter plots to visualize and interpret the relationships.

# Scatter plots for South Asia
plt.figure(figsize=(12, 5))

plt.subplot(1, 2, 1)
sns.scatterplot(x='Freedom to make life choices', y='score', data=south_asia_df, color='brown')
plt.title('South Asia: Freedom to Make Life Choices vs. Score')

plt.subplot(1, 2, 2)
sns.scatterplot(x='Generosity', y='score', data=south_asia_df, color='brown')
plt.title('South Asia: Generosity vs. Score')

plt.tight_layout()
plt.show()

# Scatter plots for Middle East
plt.figure(figsize=(12, 5))

plt.subplot(1, 2, 1)
sns.scatterplot(x='Freedom to make life choices', y='score', data=middle_east_df, color='purple')
plt.title('Middle East: Freedom to Make Life Choices vs. Score')

plt.subplot(1, 2, 2)
sns.scatterplot(x='Generosity', y='score', data=middle_east_df, color='purple')
plt.title('Middle East: Generosity vs. Score')

plt.tight_layout()
plt.show()
# Out:
# South Asia Correlation:
#                                  score  Freedom to make life choices  \
# score                         1.000000                      0.800519
# Freedom to make life choices  0.800519                      1.000000
# Generosity                    0.874512                      0.733396
#
#                               Generosity
# score                           0.874512
# Freedom to make life choices    0.733396
# Generosity                      1.000000
#
# Middle East Correlation:

# %% [markdown]
# 6. Outlier Detection:

# %%
# Outlier Detection
# Identify outlier countries in both regions based on Score and GDP per Capita.
# Plot these outliers and discuss their implications.


# Detect outliers for Score in South Asia
south_asia_score_outliers = detect_outliers(south_asia_df, 'score')

# Detect outliers for GDP per Capita in South Asia
south_asia_gdp_outliers = detect_outliers(south_asia_df, 'Log GDP per capita')

# Detect outliers for Score in Middle East
middle_east_score_outliers = detect_outliers(middle_east_df, 'score')

# Detect outliers for GDP per Capita in Middle East
middle_east_gdp_outliers = detect_outliers(middle_east_df, 'Log GDP per capita')

# Plot outliers for Score and GDP per Capita in South Asia
plt.figure(figsize=(12, 5))

plt.subplot(1, 2, 1)
sns.scatterplot(x='Log GDP per capita', y='score', data=south_asia_df, color='teal')
sns.scatterplot(x='Log GDP per capita', y='score', data=south_asia_score_outliers, color='red', label='Score Outliers')
sns.scatterplot(x='Log GDP per capita', y='score', data=south_asia_gdp_outliers, color='purple', label='GDP Outliers')
plt.title('South Asia: Outliers based on Score and GDP per Capita')
plt.legend()

plt.subplot(1, 2, 2)
sns.scatterplot(x='Log GDP per capita', y='score', data=middle_east_df, color='teal')
sns.scatterplot(x='Log GDP per capita', y='score', data=middle_east_score_outliers, color='red', label='Score Outliers')
sns.scatterplot(x='Log GDP per capita', y='score', data=middle_east_gdp_outliers, color='purple', label='GDP Outliers')
plt.title('Middle East: Outliers based on Score and GDP per Capita')
plt.legend()

plt.tight_layout()
plt.show()

# Print the outlier countries for each metric and region
print("South Asia Score Outliers:")
print(south_asia_score_outliers[['Country name', 'score']])
print("\nSouth Asia GDP Outliers:")
print(south_asia_gdp_outliers[['Country name', 'Log GDP per capita']])
print("\nMiddle East Score Outliers:")
print(middle_east_score_outliers[['Country name', 'score']])
print("\nMiddle East GDP Outliers:")
print(middle_east_gdp_outliers[['Country name', 'Log GDP per capita']])

# Discussion:
print("\nDiscussion on Outliers:")
print("- Outliers in both regions significantly deviate from the typical data points.")
print("- Score outliers indicate countries with exceptionally high or low happiness scores relative to their region.")
print("- GDP per Capita outliers highlight countries with significantly higher or lower economic output per person.")
print("- The presence of outliers can skew regional averages and may warrant further investigation.")
print("- For instance, high-GDP outliers might represent economically developed nations within a developing region,")
print("  while low-Score outliers could indicate countries facing significant social or political challenges.")
# Out:
# WARNING:matplotlib.legend:No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# South Asia Score Outliers:
# Empty DataFrame
# Columns: [Country name, score]
# Index: []
#
# South Asia GDP Outliers:
#     Country name  Log GDP per capita
# 127    Sri Lanka               1.361
#
# Middle East Score Outliers:
# Empty DataFrame
# Columns: [Country name, score]
# Index: []
#
# Middle East GDP Outliers:
# Empty DataFrame
# Columns: [Country name, Log GDP per capita]
# Index: []
#
# Discussion on Outliers:
# - Outliers in both regions significantly deviate from the typical data points.
# - Score outliers indicate countries with exceptionally high or low happiness scores relative to their region.
# - GDP per Capita outliers highlight countries with significantly higher or lower economic output per person.
# ...

# %% [markdown]
# 7. Visualization:

# %%
# prompt: • Create boxplots comparing the distribution of Score between South Asia and the Middle East.
# • Interpret the key differences in distribution shapes, medians, and outliers.

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# Load the data
try:
  df
except NameError:
  # Load the data
  df = pd.read_csv('/content/drive/MyDrive/Datasets/WHR-2024-5CS037.csv')
# Define South Asian countries
south_asian_countries = ['Bangladesh', 'Bhutan', 'India', 'Maldives', 'Nepal', 'Pakistan', 'Sri Lanka','Maldeives']

# Filter the dataset
south_asia_df = df[df['Country name'].isin(south_asian_countries)]

# Define Middle Eastern countries
middle_eastern_countries = ['Bahrain', 'Cyprus', 'Egypt', 'Israel', 'Jordan', 'Kuwait', 'Lebanon', 'Oman', 'Qatar',
                            'Saudi Arabia', 'Syria', 'Tunisia', 'United Arab Emirates']

# Filter the dataset
middle_east_data = df[df['Country name'].isin(middle_eastern_countries)]

# Create boxplots comparing the distribution of Score
plt.figure(figsize=(10, 6))
sns.boxplot(x='Region', y='score', data=pd.concat([south_asia_df.assign(Region='South Asia'), middle_east_data.assign(Region='Middle East')]), palette=['teal', 'green'])
plt.title('Distribution of Score between South Asia and Middle East')
plt.xlabel('Region')
plt.ylabel('Score')
plt.show()

# Interpret the key differences
south_asia_median = south_asia_df['score'].median()
middle_east_median = middle_east_df['score'].median()
print(f"Median Score - South Asia: {south_asia_median:.2f}")
print(f"Median Score - Middle East: {middle_east_median:.2f}")
# Analyze for outliers
def detect_outliers(df, column):
  Q1 = df[column].quantile(0.25)
  Q3 = df[column].quantile(0.75)
  IQR = Q3 - Q1
  lower_bound = Q1 - 1.5 * IQR
  upper_bound = Q3 + 1.5 * IQR
  outliers = df[(df[column] < lower_bound) | (df[column] > upper_bound)]
  return outliers

south_asia_score_outliers = detect_outliers(south_asia_df, 'score')
middle_east_score_outliers = detect_outliers(middle_east_df, 'score')
print("\nSouth Asia Score Outliers:")
print(south_asia_score_outliers[['Country name', 'score']])
print("\nMiddle East Score Outliers:")
print(middle_east_score_outliers[['Country name', 'score']])

print("\nInterpretation:")
print("1. Distribution Shapes:")
print("- Examine the shape of the boxplots (symmetric, skewed).")
print("- Compare the lengths of the whiskers and the position of the median within the box.")
print("2. Medians:")
print(f"- South Asia Median: {south_asia_median:.2f}")
print(f"- Middle East Median: {middle_east_median:.2f}")
print("- Compare the medians to see which region generally has higher scores.")
print("3. Outliers:")
print("- Identify any data points outside the whiskers (outliers).")
print("- Check for high and low outlier values and the count of outliers.")
print(f"- South Asia has {len(south_asia_score_outliers)} outlier(s) in Score")
print(f"- Middle East has {len(middle_east_score_outliers)} outlier(s) in Score")
# Out:
# <ipython-input-53-9842e565acf4>:30: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='Region', y='score', data=pd.concat([south_asia_df.assign(Region='South Asia'), middle_east_data.assign(Region='Middle East')]), palette=['teal', 'green'])
# Median Score - South Asia: 4.05
# Median Score - Middle East: 6.01
#
# South Asia Score Outliers:
# Empty DataFrame
# Columns: [Country name, score]
# Index: []
#
# Middle East Score Outliers:
# Empty DataFrame
# Columns: [Country name, score]
# Index: []
#
# Interpretation:
# 1. Distribution Shapes:
# - Examine the shape of the boxplots (symmetric, skewed).
# - Compare the lengths of the whiskers and the position of the median within the box.
# 2. Medians:
# - South Asia Median: 4.05
# - Middle East Median: 6.01
# - Compare the medians to see which region generally has higher scores.
# ...
